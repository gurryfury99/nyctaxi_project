# %%
spark.sql("create catalog if not exists nyctaxi managed location 'abfss://nyctaxi@nyctaxistorage77.dfs.core.windows.net/'")
# Out:
# DataFrame[]

# %%
spark.sql("create schema if not exists nyctaxi_00_landing")
spark.sql("create schema if not exists nyctaxi_01_bronze")
spark.sql("create schema if not exists nyctaxi_02_silver")
spark.sql("create schema if not exists nyctaxi_03_gold")
# Out:
# DataFrame[]

# %%
spark.sql("create volume if not exists nyctaxi_landing.data_sources")
# Out:
# DataFrame[]
